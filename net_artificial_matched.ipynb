# %% [markdown]
# ### Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

import tensorflow as tf
tf.keras.backend.set_floatx('float64')

from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ### Net

# %%
def createTrainingData():
  for category in CATEGORIES:
    path = os.path.join(path_test, category)
    class_num = CATEGORIES.index(category)
    for img in os.listdir(path):
      img_array = cv2.imread(os.path.join(path,img))
      new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
      training.append([new_array, CAT[class_num]])

def training_plot(metrics, history):
    f, ax = plt.subplots(1, len(metrics), figsize=(5*len(metrics), 5))
    for idx, metric in enumerate(metrics):
        ax[idx].plot(history.history[metric], ls='dashed')
        ax[idx].set_xlabel('epochs')
        ax[idx].set_ylabel(metric)
        ax[idx].plot(history.history['val_'+metric]);
        ax[idx].legend(['train_'+metric, 'val_'+metric])

# %%
IMG_SIZE=50
IMG_CHANNELS = 3
CATEGORIES = ["0","20","50","80","100","150","200","300","400"]
CAT = [0,4.54,11.31,18.05,22.52,33.63,44.64,66.37,87.72]

# %%
path_test = "E:/project_final/bulb/split_final_const/train/"
training = []
createTrainingData()

X_train =[]
y_train =[]
for features, label in training:
  X_train.append(features)
  y_train.append(label)
X_train = np.array(X_train).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X_train = X_train.astype('float32')
X_train /= 255
X_train = np.array(X_train)
y_train = np.array(y_train)

path_test = "E:/project_final/bulb/split_final_const/test/"
training = []
createTrainingData()
X_test =[]
y_test =[]
for features, label in training:
  X_test.append(features)
  y_test.append(label)
X_test = np.array(X_test).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X_test = X_test.astype('float32')
X_test /= 255
X_test = np.array(X_test)
y_test = np.array(y_test)

path_test = "E:/project_final/bulb/split_final_const/val/"
training = []
createTrainingData()
X_val =[]
y_val =[]
for features, label in training:
  X_val.append(features)
  y_val.append(label)
X_val = np.array(X_val).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X_val = X_val.astype('float32')
X_val /= 255
X_val = np.array(X_val)
y_val = np.array(y_val)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, IMG_CHANNELS)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation=None)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 128)       3584
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 128)      0
#  )
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 64)                4718656
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4,724,353
# Trainable params: 4,724,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
#tf.keras.utils.plot_model(
#    model,
#    to_file="model.png",
#    show_shapes=True,
#    show_dtype=False,
#    show_layer_names=False,
#    rankdir="TB",
#    expand_nested=False,
#    dpi=96,
#)

# %%
model.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 217/217 [==============================] - 83s 114ms/step - loss: 106.3955 - root_mean_squared_error: 10.3148 - val_loss: 40.2953 - val_root_mean_squared_error: 6.3479
# Epoch 2/50
# 217/217 [==============================] - 17s 76ms/step - loss: 39.9594 - root_mean_squared_error: 6.3213 - val_loss: 35.7493 - val_root_mean_squared_error: 5.9791
# Epoch 3/50
# 217/217 [==============================] - 16s 76ms/step - loss: 38.3129 - root_mean_squared_error: 6.1897 - val_loss: 35.8935 - val_root_mean_squared_error: 5.9911
# Epoch 4/50
# 217/217 [==============================] - 16s 76ms/step - loss: 36.2737 - root_mean_squared_error: 6.0228 - val_loss: 34.5536 - val_root_mean_squared_error: 5.8782
# Epoch 5/50
# 217/217 [==============================] - 16s 76ms/step - loss: 33.3171 - root_mean_squared_error: 5.7721 - val_loss: 35.5179 - val_root_mean_squared_error: 5.9597
# Epoch 6/50
# 217/217 [==============================] - 17s 76ms/step - loss: 33.2603 - root_mean_squared_error: 5.7672 - val_loss: 32.3939 - val_root_mean_squared_error: 5.6916
# Epoch 7/50
# 217/217 [==============================] - 17s 76ms/step - loss: 31.1765 - root_mean_squared_error: 5.5836 - val_loss: 41.5852 - val_root_mean_squared_error: 6.4487
# Epoch 8/50
# 217/217 [==============================] - 17s 76ms/step - loss: 32.0259 - root_mean_squared_error: 5.6591 - val_loss: 30.8863 - val_root_mean_squared_error: 5.5575
# Epoch 9/50
# 217/217 [==============================] - 17s 76ms/step - loss: 30.0654 - root_mean_squared_error: 5.4832 - val_loss: 46.7205 - val_root_mean_squared_error: 6.8352
# Epoch 10/50
# 217/217 [==============================] - 17s 76ms/step - loss: 27.6835 - root_mean_squared_error: 5.2615 - val_loss: 28.6331 - val_root_mean_squared_error: 5.3510
# Epoch 11/50
# 217/217 [==============================] - 17s 77ms/step - loss: 27.8132 - root_mean_squared_error: 5.2738 - val_loss: 26.0429 - val_root_mean_squared_error: 5.1032
# Epoch 12/50
# 217/217 [==============================] - 17s 76ms/step - loss: 29.0184 - root_mean_squared_error: 5.3869 - val_loss: 27.4119 - val_root_mean_squared_error: 5.2356
# Epoch 13/50
# 217/217 [==============================] - 16s 76ms/step - loss: 25.6963 - root_mean_squared_error: 5.0691 - val_loss: 35.7296 - val_root_mean_squared_error: 5.9774
# Epoch 14/50
# 217/217 [==============================] - 16s 76ms/step - loss: 21.6171 - root_mean_squared_error: 4.6494 - val_loss: 21.6415 - val_root_mean_squared_error: 4.6520
# Epoch 15/50
# 217/217 [==============================] - 16s 76ms/step - loss: 18.9539 - root_mean_squared_error: 4.3536 - val_loss: 15.7256 - val_root_mean_squared_error: 3.9656
# Epoch 16/50
# 217/217 [==============================] - 16s 76ms/step - loss: 15.9924 - root_mean_squared_error: 3.9991 - val_loss: 34.4318 - val_root_mean_squared_error: 5.8679
# Epoch 17/50
# 217/217 [==============================] - 17s 76ms/step - loss: 12.6650 - root_mean_squared_error: 3.5588 - val_loss: 6.0833 - val_root_mean_squared_error: 2.4664
# Epoch 18/50
# 217/217 [==============================] - 17s 76ms/step - loss: 7.7746 - root_mean_squared_error: 2.7883 - val_loss: 20.8073 - val_root_mean_squared_error: 4.5615
# Epoch 19/50
# 217/217 [==============================] - 17s 77ms/step - loss: 6.6597 - root_mean_squared_error: 2.5806 - val_loss: 5.5555 - val_root_mean_squared_error: 2.3570
# Epoch 20/50
# 217/217 [==============================] - 17s 76ms/step - loss: 5.8507 - root_mean_squared_error: 2.4188 - val_loss: 6.6209 - val_root_mean_squared_error: 2.5731
# Epoch 21/50
# 217/217 [==============================] - 17s 76ms/step - loss: 6.8389 - root_mean_squared_error: 2.6151 - val_loss: 4.0115 - val_root_mean_squared_error: 2.0029
# Epoch 22/50
# 217/217 [==============================] - 17s 76ms/step - loss: 4.9192 - root_mean_squared_error: 2.2179 - val_loss: 11.8812 - val_root_mean_squared_error: 3.4469
# Epoch 23/50
# 217/217 [==============================] - 17s 77ms/step - loss: 4.2672 - root_mean_squared_error: 2.0657 - val_loss: 3.3668 - val_root_mean_squared_error: 1.8349
# Epoch 24/50
# 217/217 [==============================] - 17s 76ms/step - loss: 3.6891 - root_mean_squared_error: 1.9207 - val_loss: 4.0236 - val_root_mean_squared_error: 2.0059
# Epoch 25/50
# 217/217 [==============================] - 17s 76ms/step - loss: 4.3827 - root_mean_squared_error: 2.0935 - val_loss: 4.1763 - val_root_mean_squared_error: 2.0436
# Epoch 26/50
# 217/217 [==============================] - 17s 77ms/step - loss: 4.8392 - root_mean_squared_error: 2.1998 - val_loss: 6.0912 - val_root_mean_squared_error: 2.4680
# Epoch 27/50
# 217/217 [==============================] - 17s 76ms/step - loss: 4.4378 - root_mean_squared_error: 2.1066 - val_loss: 4.3199 - val_root_mean_squared_error: 2.0784
# Epoch 28/50
# 217/217 [==============================] - 17s 77ms/step - loss: 3.6386 - root_mean_squared_error: 1.9075 - val_loss: 3.6897 - val_root_mean_squared_error: 1.9209
# Epoch 29/50
# 217/217 [==============================] - 17s 77ms/step - loss: 3.9789 - root_mean_squared_error: 1.9947 - val_loss: 3.6031 - val_root_mean_squared_error: 1.8982
# Epoch 30/50
# 217/217 [==============================] - 17s 77ms/step - loss: 4.1584 - root_mean_squared_error: 2.0392 - val_loss: 10.1757 - val_root_mean_squared_error: 3.1899
# Epoch 31/50
# 217/217 [==============================] - 17s 77ms/step - loss: 7.2953 - root_mean_squared_error: 2.7010 - val_loss: 3.2082 - val_root_mean_squared_error: 1.7911
# Epoch 32/50
# 217/217 [==============================] - 17s 77ms/step - loss: 4.2300 - root_mean_squared_error: 2.0567 - val_loss: 3.5857 - val_root_mean_squared_error: 1.8936
# Epoch 33/50
# 217/217 [==============================] - 17s 77ms/step - loss: 3.8934 - root_mean_squared_error: 1.9732 - val_loss: 4.0121 - val_root_mean_squared_error: 2.0030
# Epoch 34/50
# 217/217 [==============================] - 17s 77ms/step - loss: 4.5332 - root_mean_squared_error: 2.1291 - val_loss: 4.1960 - val_root_mean_squared_error: 2.0484
# Epoch 35/50
# 217/217 [==============================] - 17s 78ms/step - loss: 3.4500 - root_mean_squared_error: 1.8574 - val_loss: 3.5088 - val_root_mean_squared_error: 1.8732
# Epoch 36/50
# 217/217 [==============================] - 17s 77ms/step - loss: 3.7300 - root_mean_squared_error: 1.9313 - val_loss: 3.9140 - val_root_mean_squared_error: 1.9784
# Epoch 37/50
# 217/217 [==============================] - 17s 77ms/step - loss: 3.7621 - root_mean_squared_error: 1.9396 - val_loss: 3.1088 - val_root_mean_squared_error: 1.7632
# Epoch 38/50
# 217/217 [==============================] - 17s 77ms/step - loss: 3.7465 - root_mean_squared_error: 1.9356 - val_loss: 3.6030 - val_root_mean_squared_error: 1.8982
# Epoch 39/50
# 217/217 [==============================] - 17s 77ms/step - loss: 3.9724 - root_mean_squared_error: 1.9931 - val_loss: 2.9532 - val_root_mean_squared_error: 1.7185
# Epoch 40/50
# 217/217 [==============================] - 17s 77ms/step - loss: 3.7559 - root_mean_squared_error: 1.9380 - val_loss: 4.0410 - val_root_mean_squared_error: 2.0102
# Epoch 41/50
# 217/217 [==============================] - 17s 77ms/step - loss: 6.6797 - root_mean_squared_error: 2.5845 - val_loss: 4.7532 - val_root_mean_squared_error: 2.1802
# Epoch 42/50
# 217/217 [==============================] - 17s 77ms/step - loss: 4.1548 - root_mean_squared_error: 2.0383 - val_loss: 3.5827 - val_root_mean_squared_error: 1.8928
# Epoch 43/50
# 217/217 [==============================] - 17s 77ms/step - loss: 3.3296 - root_mean_squared_error: 1.8247 - val_loss: 3.5016 - val_root_mean_squared_error: 1.8712
# Epoch 44/50
# 217/217 [==============================] - 17s 77ms/step - loss: 3.8513 - root_mean_squared_error: 1.9625 - val_loss: 3.3398 - val_root_mean_squared_error: 1.8275
# Epoch 45/50
# 217/217 [==============================] - 17s 77ms/step - loss: 3.9339 - root_mean_squared_error: 1.9834 - val_loss: 2.9217 - val_root_mean_squared_error: 1.7093
# Epoch 46/50
# 217/217 [==============================] - 17s 78ms/step - loss: 3.3394 - root_mean_squared_error: 1.8274 - val_loss: 4.5001 - val_root_mean_squared_error: 2.1213
# Epoch 47/50
# 217/217 [==============================] - 17s 77ms/step - loss: 9.5344 - root_mean_squared_error: 3.0878 - val_loss: 3.2431 - val_root_mean_squared_error: 1.8008
# Epoch 48/50
# 217/217 [==============================] - 17s 77ms/step - loss: 3.1176 - root_mean_squared_error: 1.7657 - val_loss: 4.3471 - val_root_mean_squared_error: 2.0850
# Epoch 49/50
# 217/217 [==============================] - 17s 77ms/step - loss: 2.8297 - root_mean_squared_error: 1.6822 - val_loss: 2.7073 - val_root_mean_squared_error: 1.6454
# Epoch 50/50
# 217/217 [==============================] - 17s 77ms/step - loss: 2.8575 - root_mean_squared_error: 1.6904 - val_loss: 2.8008 - val_root_mean_squared_error: 1.6736

# %%
training_plot(['loss', 'root_mean_squared_error'], history)

# %%
prediction = model.predict(X_test)

#create basic scatterplot
plt.plot(y_test, prediction, '.')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(y_test, prediction, 1)

#add linear regression line to scatterplot 
plt.plot(y_test, m*y_test+b)
plt.grid()
plt.xlabel('original [μg/ml]') 
plt.ylabel('predicted [μg/ml]') 

# model evaluation 
mse=mean_squared_error(y_test,prediction) 
rmse = np.sqrt(mean_squared_error(y_test,prediction)) 
r2 = r2_score(y_test,prediction) 

# printing values 
print('Slope:' , m) 
print('Intercept:', b) 
print('MSE:', mse) 
print('Root mean squared error: ', rmse) 
print('R2 score: ', r2)
# Out:
# 47/47 [==============================] - 1s 28ms/step
# Slope: [1.01378086]
# Intercept: [-0.35957328]
# MSE: 2.916097819188579
# Root mean squared error:  1.7076585780502433
# R2 score:  0.9962177582237801

# %%
prediction_g=prediction.reshape(-1, 165)
mean_pred=[]
std_pred=[]
for i in range(9):
    mean_pred.append(np.mean(prediction_g[i]))
    std_pred.append(np.std(prediction_g[i]))

plt.errorbar(CAT, mean_pred, std_pred, linestyle='None', marker='.')
plt.plot(CAT, m*CAT+b)
plt.grid()
plt.xlabel('original [μg/ml]') 
plt.ylabel('predicted [μg/ml]') 

plt.show()
