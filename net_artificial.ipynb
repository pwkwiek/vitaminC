# %% [markdown]
# ### Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

import tensorflow as tf
tf.keras.backend.set_floatx('float64')

from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ### Net

# %%
def createTrainingData():
  for category in CATEGORIES:
    path = os.path.join(path_test, category)
    class_num = CATEGORIES.index(category)
    for img in os.listdir(path):
      img_array = cv2.imread(os.path.join(path,img))
      new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
      training.append([new_array, CAT[class_num]])

def training_plot(metrics, history):
    f, ax = plt.subplots(1, len(metrics), figsize=(5*len(metrics), 5))
    for idx, metric in enumerate(metrics):
        ax[idx].plot(history.history[metric], ls='dashed')
        ax[idx].set_xlabel('epochs')
        ax[idx].set_ylabel(metric)
        ax[idx].plot(history.history['val_'+metric]);
        ax[idx].legend(['train_'+metric, 'val_'+metric])

# %%
IMG_SIZE=50
IMG_CHANNELS = 3
CATEGORIES = ["0","20","50","80","100","150","200","300","400"]
CAT = [0,4.54,11.31,18.05,22.52,33.63,44.64,66.37,87.72]

# %%
path_test = "E:/project_final/bulb/split_final_org/train/"
training = []
createTrainingData()

X_train =[]
y_train =[]
for features, label in training:
  X_train.append(features)
  y_train.append(label)
X_train = np.array(X_train).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X_train = X_train.astype('float32')
X_train /= 255
X_train = np.array(X_train)
y_train = np.array(y_train)

path_test = "E:/project_final/bulb/split_final_org/test/"
training = []
createTrainingData()
X_test =[]
y_test =[]
for features, label in training:
  X_test.append(features)
  y_test.append(label)
X_test = np.array(X_test).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X_test = X_test.astype('float32')
X_test /= 255
X_test = np.array(X_test)
y_test = np.array(y_test)

path_test = "E:/project_final/bulb/split_final_org/val/"
training = []
createTrainingData()
X_val =[]
y_val =[]
for features, label in training:
  X_val.append(features)
  y_val.append(label)
X_val = np.array(X_val).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X_val = X_val.astype('float32')
X_val /= 255
X_val = np.array(X_val)
y_val = np.array(y_val)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, IMG_CHANNELS)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation=None)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 128)       3584
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 128)      0
#  )
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 64)                4718656
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4,724,353
# Trainable params: 4,724,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
#tf.keras.utils.plot_model(
#    model,
#    to_file="model.png",
#    show_shapes=True,
#    show_dtype=False,
#    show_layer_names=False,
#    rankdir="TB",
#    expand_nested=False,
#    dpi=96,
#)

# %%
model.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 217/217 [==============================] - 60s 78ms/step - loss: 152.4265 - root_mean_squared_error: 12.3461 - val_loss: 58.8958 - val_root_mean_squared_error: 7.6744
# Epoch 2/50
# 217/217 [==============================] - 16s 76ms/step - loss: 63.2690 - root_mean_squared_error: 7.9542 - val_loss: 47.4778 - val_root_mean_squared_error: 6.8904
# Epoch 3/50
# 217/217 [==============================] - 16s 76ms/step - loss: 53.4582 - root_mean_squared_error: 7.3115 - val_loss: 41.4247 - val_root_mean_squared_error: 6.4362
# Epoch 4/50
# 217/217 [==============================] - 16s 76ms/step - loss: 46.4405 - root_mean_squared_error: 6.8147 - val_loss: 43.3550 - val_root_mean_squared_error: 6.5845
# Epoch 5/50
# 217/217 [==============================] - 16s 76ms/step - loss: 53.8979 - root_mean_squared_error: 7.3415 - val_loss: 38.3854 - val_root_mean_squared_error: 6.1956
# Epoch 6/50
# 217/217 [==============================] - 16s 75ms/step - loss: 49.1820 - root_mean_squared_error: 7.0130 - val_loss: 44.6687 - val_root_mean_squared_error: 6.6835
# Epoch 7/50
# 217/217 [==============================] - 16s 76ms/step - loss: 42.2896 - root_mean_squared_error: 6.5030 - val_loss: 39.6262 - val_root_mean_squared_error: 6.2949
# Epoch 8/50
# 217/217 [==============================] - 16s 76ms/step - loss: 49.5464 - root_mean_squared_error: 7.0389 - val_loss: 51.9254 - val_root_mean_squared_error: 7.2059
# Epoch 9/50
# 217/217 [==============================] - 16s 76ms/step - loss: 53.0171 - root_mean_squared_error: 7.2813 - val_loss: 74.8206 - val_root_mean_squared_error: 8.6499
# Epoch 10/50
# 217/217 [==============================] - 17s 78ms/step - loss: 44.9055 - root_mean_squared_error: 6.7012 - val_loss: 110.5335 - val_root_mean_squared_error: 10.5135
# Epoch 11/50
# 217/217 [==============================] - 17s 77ms/step - loss: 48.0255 - root_mean_squared_error: 6.9300 - val_loss: 45.8703 - val_root_mean_squared_error: 6.7728
# Epoch 12/50
# 217/217 [==============================] - 17s 76ms/step - loss: 41.7652 - root_mean_squared_error: 6.4626 - val_loss: 41.8909 - val_root_mean_squared_error: 6.4723
# Epoch 13/50
# 217/217 [==============================] - 17s 76ms/step - loss: 47.2634 - root_mean_squared_error: 6.8748 - val_loss: 36.1145 - val_root_mean_squared_error: 6.0095
# Epoch 14/50
# 217/217 [==============================] - 17s 76ms/step - loss: 44.4184 - root_mean_squared_error: 6.6647 - val_loss: 66.5373 - val_root_mean_squared_error: 8.1570
# Epoch 15/50
# 217/217 [==============================] - 17s 77ms/step - loss: 41.3610 - root_mean_squared_error: 6.4313 - val_loss: 33.6129 - val_root_mean_squared_error: 5.7977
# Epoch 16/50
# 217/217 [==============================] - 16s 76ms/step - loss: 38.6268 - root_mean_squared_error: 6.2150 - val_loss: 33.5922 - val_root_mean_squared_error: 5.7959
# Epoch 17/50
# 217/217 [==============================] - 16s 76ms/step - loss: 39.0777 - root_mean_squared_error: 6.2512 - val_loss: 38.4585 - val_root_mean_squared_error: 6.2015
# Epoch 18/50
# 217/217 [==============================] - 17s 77ms/step - loss: 39.9424 - root_mean_squared_error: 6.3200 - val_loss: 37.2091 - val_root_mean_squared_error: 6.0999
# Epoch 19/50
# 217/217 [==============================] - 17s 77ms/step - loss: 36.9091 - root_mean_squared_error: 6.0753 - val_loss: 37.3328 - val_root_mean_squared_error: 6.1101
# Epoch 20/50
# 217/217 [==============================] - 17s 76ms/step - loss: 39.7835 - root_mean_squared_error: 6.3074 - val_loss: 40.0100 - val_root_mean_squared_error: 6.3253
# Epoch 21/50
# 217/217 [==============================] - 17s 76ms/step - loss: 40.8389 - root_mean_squared_error: 6.3905 - val_loss: 55.2338 - val_root_mean_squared_error: 7.4319
# Epoch 22/50
# 217/217 [==============================] - 17s 76ms/step - loss: 43.9653 - root_mean_squared_error: 6.6306 - val_loss: 60.6108 - val_root_mean_squared_error: 7.7853
# Epoch 23/50
# 217/217 [==============================] - 17s 77ms/step - loss: 38.4796 - root_mean_squared_error: 6.2032 - val_loss: 48.6060 - val_root_mean_squared_error: 6.9718
# Epoch 24/50
# 217/217 [==============================] - 17s 77ms/step - loss: 40.9925 - root_mean_squared_error: 6.4025 - val_loss: 31.7531 - val_root_mean_squared_error: 5.6350
# Epoch 25/50
# 217/217 [==============================] - 17s 77ms/step - loss: 40.2313 - root_mean_squared_error: 6.3428 - val_loss: 34.2955 - val_root_mean_squared_error: 5.8562
# Epoch 26/50
# 217/217 [==============================] - 17s 77ms/step - loss: 39.6907 - root_mean_squared_error: 6.3001 - val_loss: 31.3528 - val_root_mean_squared_error: 5.5994
# Epoch 27/50
# 217/217 [==============================] - 17s 77ms/step - loss: 35.4967 - root_mean_squared_error: 5.9579 - val_loss: 33.1115 - val_root_mean_squared_error: 5.7543
# Epoch 28/50
# 217/217 [==============================] - 17s 77ms/step - loss: 36.0273 - root_mean_squared_error: 6.0023 - val_loss: 33.7794 - val_root_mean_squared_error: 5.8120
# Epoch 29/50
# 217/217 [==============================] - 17s 77ms/step - loss: 38.3696 - root_mean_squared_error: 6.1943 - val_loss: 44.2390 - val_root_mean_squared_error: 6.6512
# Epoch 30/50
# 217/217 [==============================] - 17s 77ms/step - loss: 36.2895 - root_mean_squared_error: 6.0241 - val_loss: 34.2447 - val_root_mean_squared_error: 5.8519
# Epoch 31/50
# 217/217 [==============================] - 17s 78ms/step - loss: 35.4530 - root_mean_squared_error: 5.9542 - val_loss: 31.5805 - val_root_mean_squared_error: 5.6196
# Epoch 32/50
# 217/217 [==============================] - 17s 78ms/step - loss: 40.4266 - root_mean_squared_error: 6.3582 - val_loss: 50.6226 - val_root_mean_squared_error: 7.1150
# Epoch 33/50
# 217/217 [==============================] - 17s 78ms/step - loss: 36.9432 - root_mean_squared_error: 6.0781 - val_loss: 31.5835 - val_root_mean_squared_error: 5.6199
# Epoch 34/50
# 217/217 [==============================] - 17s 77ms/step - loss: 35.0569 - root_mean_squared_error: 5.9209 - val_loss: 58.6231 - val_root_mean_squared_error: 7.6566
# Epoch 35/50
# 217/217 [==============================] - 17s 78ms/step - loss: 36.5613 - root_mean_squared_error: 6.0466 - val_loss: 29.7875 - val_root_mean_squared_error: 5.4578
# Epoch 36/50
# 217/217 [==============================] - 17s 77ms/step - loss: 36.0442 - root_mean_squared_error: 6.0037 - val_loss: 70.4042 - val_root_mean_squared_error: 8.3907
# Epoch 37/50
# 217/217 [==============================] - 17s 77ms/step - loss: 42.0443 - root_mean_squared_error: 6.4842 - val_loss: 37.1064 - val_root_mean_squared_error: 6.0915
# Epoch 38/50
# 217/217 [==============================] - 17s 77ms/step - loss: 35.7732 - root_mean_squared_error: 5.9811 - val_loss: 31.0878 - val_root_mean_squared_error: 5.5756
# Epoch 39/50
# 217/217 [==============================] - 17s 78ms/step - loss: 36.2322 - root_mean_squared_error: 6.0193 - val_loss: 34.6582 - val_root_mean_squared_error: 5.8871
# Epoch 40/50
# 217/217 [==============================] - 17s 78ms/step - loss: 33.7119 - root_mean_squared_error: 5.8062 - val_loss: 39.8937 - val_root_mean_squared_error: 6.3161
# Epoch 41/50
# 217/217 [==============================] - 17s 77ms/step - loss: 33.7018 - root_mean_squared_error: 5.8053 - val_loss: 32.4631 - val_root_mean_squared_error: 5.6976
# Epoch 42/50
# 217/217 [==============================] - 17s 77ms/step - loss: 35.1525 - root_mean_squared_error: 5.9290 - val_loss: 35.0587 - val_root_mean_squared_error: 5.9210
# Epoch 43/50
# 217/217 [==============================] - 17s 77ms/step - loss: 32.6688 - root_mean_squared_error: 5.7157 - val_loss: 32.2165 - val_root_mean_squared_error: 5.6760
# Epoch 44/50
# 217/217 [==============================] - 17s 77ms/step - loss: 33.0956 - root_mean_squared_error: 5.7529 - val_loss: 28.5000 - val_root_mean_squared_error: 5.3385
# Epoch 45/50
# 217/217 [==============================] - 17s 77ms/step - loss: 29.9124 - root_mean_squared_error: 5.4692 - val_loss: 32.1118 - val_root_mean_squared_error: 5.6667
# Epoch 46/50
# 217/217 [==============================] - 17s 77ms/step - loss: 31.4588 - root_mean_squared_error: 5.6088 - val_loss: 28.2740 - val_root_mean_squared_error: 5.3173
# Epoch 47/50
# 217/217 [==============================] - 17s 77ms/step - loss: 29.1800 - root_mean_squared_error: 5.4019 - val_loss: 31.8479 - val_root_mean_squared_error: 5.6434
# Epoch 48/50
# 217/217 [==============================] - 17s 77ms/step - loss: 32.2557 - root_mean_squared_error: 5.6794 - val_loss: 21.9838 - val_root_mean_squared_error: 4.6887
# Epoch 49/50
# 217/217 [==============================] - 17s 77ms/step - loss: 30.8805 - root_mean_squared_error: 5.5570 - val_loss: 22.6251 - val_root_mean_squared_error: 4.7566
# Epoch 50/50
# 217/217 [==============================] - 17s 77ms/step - loss: 28.8753 - root_mean_squared_error: 5.3736 - val_loss: 33.7695 - val_root_mean_squared_error: 5.8112

# %%
training_plot(['loss', 'root_mean_squared_error'], history)

# %%
prediction = model.predict(X_test)

#create basic scatterplot
plt.plot(y_test, prediction, '.')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(y_test, prediction, 1)

#add linear regression line to scatterplot 
plt.plot(y_test, m*y_test+b)
plt.grid()
plt.xlabel('original [μg/ml]') 
plt.ylabel('predicted [μg/ml]') 

# model evaluation 
mse=mean_squared_error(y_test,prediction) 
rmse = np.sqrt(mean_squared_error(y_test,prediction)) 
r2 = r2_score(y_test,prediction) 

# printing values 
print('Slope:' , m) 
print('Intercept:', b) 
print('MSE:', mse) 
print('Root mean squared error: ', rmse) 
print('R2 score: ', r2)
# Out:
# 47/47 [==============================] - 1s 24ms/step
# Slope: [0.90584553]
# Intercept: [0.68906914]
# MSE: 34.12341565678886
# Root mean squared error:  5.841525113939754
# R2 score:  0.9557411937983836

# %%
prediction_g=prediction.reshape(-1, 165)
mean_pred=[]
std_pred=[]
for i in range(9):
    mean_pred.append(np.mean(prediction_g[i]))
    std_pred.append(np.std(prediction_g[i]))

plt.errorbar(CAT, mean_pred, std_pred, linestyle='None', marker='.')
plt.plot(CAT, m*CAT+b)
plt.grid()
plt.xlabel('original [μg/ml]') 
plt.ylabel('predicted [μg/ml]') 

plt.show()
