# %% [markdown]
# ### Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

import tensorflow as tf
tf.keras.backend.set_floatx('float64')

from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ### Net

# %%
def createTrainingData():
  for category in CATEGORIES:
    path = os.path.join(path_test, category)
    class_num = CATEGORIES.index(category)
    for img in os.listdir(path):
      img_array = cv2.imread(os.path.join(path,img))
      new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
      training.append([new_array, CAT[class_num]])

def training_plot(metrics, history):
    f, ax = plt.subplots(1, len(metrics), figsize=(5*len(metrics), 5))
    for idx, metric in enumerate(metrics):
        ax[idx].plot(history.history[metric], ls='dashed')
        ax[idx].set_xlabel('epochs')
        ax[idx].set_ylabel(metric)
        ax[idx].plot(history.history['val_'+metric]);
        ax[idx].legend(['train_'+metric, 'val_'+metric])

# %%
IMG_SIZE=50
IMG_CHANNELS = 3
CATEGORIES = ["0","20","50","80","100","150","200","300","400"]
CAT = [0,4.54,11.31,18.05,22.52,33.63,44.64,66.37,87.72]

# %%
path_test = "E:/project_final/mixed/split_final_org/train/"
training = []
createTrainingData()

X_train =[]
y_train =[]
for features, label in training:
  X_train.append(features)
  y_train.append(label)
X_train = np.array(X_train).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X_train = X_train.astype('float32')
X_train /= 255
X_train = np.array(X_train)
y_train = np.array(y_train)

path_test = "E:/project_final/mixed/split_final_org/test/"
training = []
createTrainingData()
X_test =[]
y_test =[]
for features, label in training:
  X_test.append(features)
  y_test.append(label)
X_test = np.array(X_test).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X_test = X_test.astype('float32')
X_test /= 255
X_test = np.array(X_test)
y_test = np.array(y_test)

path_test = "E:/project_final/mixed/split_final_org/val/"
training = []
createTrainingData()
X_val =[]
y_val =[]
for features, label in training:
  X_val.append(features)
  y_val.append(label)
X_val = np.array(X_val).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X_val = X_val.astype('float32')
X_val /= 255
X_val = np.array(X_val)
y_val = np.array(y_val)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, IMG_CHANNELS)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation=None)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 128)       3584
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 128)      0
#  )
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 64)                4718656
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4,724,353
# Trainable params: 4,724,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
#tf.keras.utils.plot_model(
#    model,
#    to_file="model.png",
#    show_shapes=True,
#    show_dtype=False,
#    show_layer_names=False,
#    rankdir="TB",
#    expand_nested=False,
#    dpi=96,
#)

# %%
model.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 434/434 [==============================] - 81s 93ms/step - loss: 126.3898 - root_mean_squared_error: 11.2423 - val_loss: 65.0827 - val_root_mean_squared_error: 8.0674
# Epoch 2/50
# 434/434 [==============================] - 37s 86ms/step - loss: 60.2890 - root_mean_squared_error: 7.7646 - val_loss: 58.0123 - val_root_mean_squared_error: 7.6166
# Epoch 3/50
# 434/434 [==============================] - 37s 85ms/step - loss: 42.0411 - root_mean_squared_error: 6.4839 - val_loss: 57.3893 - val_root_mean_squared_error: 7.5756
# Epoch 4/50
# 434/434 [==============================] - 37s 86ms/step - loss: 42.4417 - root_mean_squared_error: 6.5147 - val_loss: 32.3143 - val_root_mean_squared_error: 5.6846
# Epoch 5/50
# 434/434 [==============================] - 38s 87ms/step - loss: 39.2862 - root_mean_squared_error: 6.2679 - val_loss: 41.6570 - val_root_mean_squared_error: 6.4542
# Epoch 6/50
# 434/434 [==============================] - 37s 86ms/step - loss: 32.9099 - root_mean_squared_error: 5.7367 - val_loss: 26.1882 - val_root_mean_squared_error: 5.1174
# Epoch 7/50
# 434/434 [==============================] - 37s 86ms/step - loss: 34.7211 - root_mean_squared_error: 5.8925 - val_loss: 29.6716 - val_root_mean_squared_error: 5.4472
# Epoch 8/50
# 434/434 [==============================] - 37s 86ms/step - loss: 33.9685 - root_mean_squared_error: 5.8283 - val_loss: 24.4881 - val_root_mean_squared_error: 4.9485
# Epoch 9/50
# 434/434 [==============================] - 37s 86ms/step - loss: 34.1312 - root_mean_squared_error: 5.8422 - val_loss: 37.7680 - val_root_mean_squared_error: 6.1456
# Epoch 10/50
# 434/434 [==============================] - 38s 87ms/step - loss: 29.8749 - root_mean_squared_error: 5.4658 - val_loss: 23.6241 - val_root_mean_squared_error: 4.8605
# Epoch 11/50
# 434/434 [==============================] - 37s 86ms/step - loss: 31.7032 - root_mean_squared_error: 5.6306 - val_loss: 28.1158 - val_root_mean_squared_error: 5.3024
# Epoch 12/50
# 434/434 [==============================] - 38s 87ms/step - loss: 31.9611 - root_mean_squared_error: 5.6534 - val_loss: 29.9542 - val_root_mean_squared_error: 5.4730
# Epoch 13/50
# 434/434 [==============================] - 38s 87ms/step - loss: 35.7684 - root_mean_squared_error: 5.9807 - val_loss: 29.9666 - val_root_mean_squared_error: 5.4742
# Epoch 14/50
# 434/434 [==============================] - 38s 87ms/step - loss: 29.5458 - root_mean_squared_error: 5.4356 - val_loss: 36.4770 - val_root_mean_squared_error: 6.0396
# Epoch 15/50
# 434/434 [==============================] - 38s 87ms/step - loss: 30.9016 - root_mean_squared_error: 5.5589 - val_loss: 48.4308 - val_root_mean_squared_error: 6.9592
# Epoch 16/50
# 434/434 [==============================] - 38s 89ms/step - loss: 30.4369 - root_mean_squared_error: 5.5170 - val_loss: 27.1727 - val_root_mean_squared_error: 5.2127
# Epoch 17/50
# 434/434 [==============================] - 38s 88ms/step - loss: 28.6003 - root_mean_squared_error: 5.3479 - val_loss: 30.5692 - val_root_mean_squared_error: 5.5289
# Epoch 18/50
# 434/434 [==============================] - 38s 88ms/step - loss: 28.0483 - root_mean_squared_error: 5.2961 - val_loss: 43.5359 - val_root_mean_squared_error: 6.5982
# Epoch 19/50
# 434/434 [==============================] - 38s 87ms/step - loss: 29.2425 - root_mean_squared_error: 5.4076 - val_loss: 21.9631 - val_root_mean_squared_error: 4.6865
# Epoch 20/50
# 434/434 [==============================] - 37s 86ms/step - loss: 30.3190 - root_mean_squared_error: 5.5063 - val_loss: 24.6267 - val_root_mean_squared_error: 4.9625
# Epoch 21/50
# 434/434 [==============================] - 37s 85ms/step - loss: 28.9759 - root_mean_squared_error: 5.3829 - val_loss: 21.7286 - val_root_mean_squared_error: 4.6614
# Epoch 22/50
# 434/434 [==============================] - 36s 84ms/step - loss: 26.0656 - root_mean_squared_error: 5.1055 - val_loss: 23.3695 - val_root_mean_squared_error: 4.8342
# Epoch 23/50
# 434/434 [==============================] - 36s 83ms/step - loss: 29.3769 - root_mean_squared_error: 5.4200 - val_loss: 21.9782 - val_root_mean_squared_error: 4.6881
# Epoch 24/50
# 434/434 [==============================] - 37s 86ms/step - loss: 26.7049 - root_mean_squared_error: 5.1677 - val_loss: 23.1695 - val_root_mean_squared_error: 4.8135
# Epoch 25/50
# 434/434 [==============================] - 37s 86ms/step - loss: 25.8016 - root_mean_squared_error: 5.0795 - val_loss: 23.9481 - val_root_mean_squared_error: 4.8937
# Epoch 26/50
# 434/434 [==============================] - 37s 86ms/step - loss: 26.8481 - root_mean_squared_error: 5.1815 - val_loss: 20.8887 - val_root_mean_squared_error: 4.5704
# Epoch 27/50
# 434/434 [==============================] - 38s 87ms/step - loss: 28.2823 - root_mean_squared_error: 5.3181 - val_loss: 29.4833 - val_root_mean_squared_error: 5.4299
# Epoch 28/50
# 434/434 [==============================] - 37s 86ms/step - loss: 27.3780 - root_mean_squared_error: 5.2324 - val_loss: 23.9974 - val_root_mean_squared_error: 4.8987
# Epoch 29/50
# 434/434 [==============================] - 38s 87ms/step - loss: 25.7166 - root_mean_squared_error: 5.0712 - val_loss: 21.2082 - val_root_mean_squared_error: 4.6052
# Epoch 30/50
# 434/434 [==============================] - 38s 87ms/step - loss: 24.6783 - root_mean_squared_error: 4.9677 - val_loss: 25.8915 - val_root_mean_squared_error: 5.0884
# Epoch 31/50
# 434/434 [==============================] - 37s 86ms/step - loss: 26.0409 - root_mean_squared_error: 5.1030 - val_loss: 23.6314 - val_root_mean_squared_error: 4.8612
# Epoch 32/50
# 434/434 [==============================] - 38s 87ms/step - loss: 25.3515 - root_mean_squared_error: 5.0350 - val_loss: 28.7405 - val_root_mean_squared_error: 5.3610
# Epoch 33/50
# 434/434 [==============================] - 38s 87ms/step - loss: 27.1868 - root_mean_squared_error: 5.2141 - val_loss: 20.8087 - val_root_mean_squared_error: 4.5617
# Epoch 34/50
# 434/434 [==============================] - 38s 87ms/step - loss: 24.4841 - root_mean_squared_error: 4.9481 - val_loss: 34.0509 - val_root_mean_squared_error: 5.8353
# Epoch 35/50
# 434/434 [==============================] - 38s 87ms/step - loss: 24.1779 - root_mean_squared_error: 4.9171 - val_loss: 32.5439 - val_root_mean_squared_error: 5.7047
# Epoch 36/50
# 434/434 [==============================] - 38s 87ms/step - loss: 23.9612 - root_mean_squared_error: 4.8950 - val_loss: 21.2154 - val_root_mean_squared_error: 4.6060
# Epoch 37/50
# 434/434 [==============================] - 38s 87ms/step - loss: 23.5873 - root_mean_squared_error: 4.8567 - val_loss: 21.5018 - val_root_mean_squared_error: 4.6370
# Epoch 38/50
# 434/434 [==============================] - 38s 87ms/step - loss: 22.6262 - root_mean_squared_error: 4.7567 - val_loss: 16.6081 - val_root_mean_squared_error: 4.0753
# Epoch 39/50
# 434/434 [==============================] - 38s 87ms/step - loss: 22.3751 - root_mean_squared_error: 4.7302 - val_loss: 24.1389 - val_root_mean_squared_error: 4.9131
# Epoch 40/50
# 434/434 [==============================] - 38s 87ms/step - loss: 22.0576 - root_mean_squared_error: 4.6966 - val_loss: 15.1015 - val_root_mean_squared_error: 3.8861
# Epoch 41/50
# 434/434 [==============================] - 38s 87ms/step - loss: 23.6800 - root_mean_squared_error: 4.8662 - val_loss: 14.0222 - val_root_mean_squared_error: 3.7446
# Epoch 42/50
# 434/434 [==============================] - 38s 87ms/step - loss: 20.9438 - root_mean_squared_error: 4.5764 - val_loss: 32.4009 - val_root_mean_squared_error: 5.6922
# Epoch 43/50
# 434/434 [==============================] - 37s 86ms/step - loss: 22.7578 - root_mean_squared_error: 4.7705 - val_loss: 14.9328 - val_root_mean_squared_error: 3.8643
# Epoch 44/50
# 434/434 [==============================] - 38s 87ms/step - loss: 20.2172 - root_mean_squared_error: 4.4963 - val_loss: 22.7688 - val_root_mean_squared_error: 4.7717
# Epoch 45/50
# 434/434 [==============================] - 38s 87ms/step - loss: 18.8233 - root_mean_squared_error: 4.3386 - val_loss: 44.9163 - val_root_mean_squared_error: 6.7020
# Epoch 46/50
# 434/434 [==============================] - 38s 87ms/step - loss: 23.4378 - root_mean_squared_error: 4.8413 - val_loss: 27.7662 - val_root_mean_squared_error: 5.2694
# Epoch 47/50
# 434/434 [==============================] - 38s 87ms/step - loss: 20.2805 - root_mean_squared_error: 4.5034 - val_loss: 20.1626 - val_root_mean_squared_error: 4.4903
# Epoch 48/50
# 434/434 [==============================] - 38s 87ms/step - loss: 22.1002 - root_mean_squared_error: 4.7011 - val_loss: 20.1987 - val_root_mean_squared_error: 4.4943
# Epoch 49/50
# 434/434 [==============================] - 38s 86ms/step - loss: 16.5209 - root_mean_squared_error: 4.0646 - val_loss: 18.0174 - val_root_mean_squared_error: 4.2447
# Epoch 50/50
# 434/434 [==============================] - 38s 87ms/step - loss: 17.4842 - root_mean_squared_error: 4.1814 - val_loss: 16.6666 - val_root_mean_squared_error: 4.0825

# %%
training_plot(['loss', 'root_mean_squared_error'], history)

# %%
prediction = model.predict(X_test)

#create basic scatterplot
plt.plot(y_test, prediction, '.')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(y_test, prediction, 1)

#add linear regression line to scatterplot 
plt.plot(y_test, m*y_test+b)
plt.grid()
plt.xlabel('original [μg/ml]') 
plt.ylabel('predicted [μg/ml]') 

# model evaluation 
mse=mean_squared_error(y_test,prediction) 
rmse = np.sqrt(mean_squared_error(y_test,prediction)) 
r2 = r2_score(y_test,prediction) 

# printing values 
print('Slope:' , m) 
print('Intercept:', b) 
print('MSE:', mse) 
print('Root mean squared error: ', rmse) 
print('R2 score: ', r2)
# Out:
# 93/93 [==============================] - 3s 29ms/step
# Slope: [1.00050048]
# Intercept: [0.87470532]
# MSE: 18.91215205019987
# Root mean squared error:  4.348810417826911
# R2 score:  0.9754705308265713

# %%
prediction_g=prediction.reshape(-1, 330)
mean_pred=[]
std_pred=[]
for i in range(9):
    mean_pred.append(np.mean(prediction_g[i]))
    std_pred.append(np.std(prediction_g[i]))

plt.errorbar(CAT, mean_pred, std_pred, linestyle='None', marker='.')
plt.plot(CAT, m*CAT+b)
plt.grid()
plt.xlabel('original vitamin C concentration [μg/ml]') 
plt.ylabel('predicted vitamin C concentration [μg/ml]') 
plt.legend(["regression line", "mean value with standard deviation"], fontsize=10)
plt.show()
