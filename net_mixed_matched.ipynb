# %% [markdown]
# ### Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

import tensorflow as tf
tf.keras.backend.set_floatx('float64')

from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ### Net

# %%
def createTrainingData():
  for category in CATEGORIES:
    path = os.path.join(path_test, category)
    class_num = CATEGORIES.index(category)
    for img in os.listdir(path):
      img_array = cv2.imread(os.path.join(path,img))
      new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
      training.append([new_array, CAT[class_num]])

def training_plot(metrics, history):
    f, ax = plt.subplots(1, len(metrics), figsize=(5*len(metrics), 5))
    for idx, metric in enumerate(metrics):
        ax[idx].plot(history.history[metric], ls='dashed')
        ax[idx].set_xlabel('epochs')
        ax[idx].set_ylabel(metric)
        ax[idx].plot(history.history['val_'+metric]);
        ax[idx].legend(['train_'+metric, 'val_'+metric])

# %%
IMG_SIZE=50
IMG_CHANNELS = 3
CATEGORIES = ["0","20","50","80","100","150","200","300","400"]
CAT = [0,4.54,11.31,18.05,22.52,33.63,44.64,66.37,87.72]

# %%
path_test = "E:/project_final/mixed/split_final_const/train/"
training = []
createTrainingData()

X_train =[]
y_train =[]
for features, label in training:
  X_train.append(features)
  y_train.append(label)
X_train = np.array(X_train).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X_train = X_train.astype('float32')
X_train /= 255
X_train = np.array(X_train)
y_train = np.array(y_train)

path_test = "E:/project_final/mixed/split_final_const/test/"
training = []
createTrainingData()
X_test =[]
y_test =[]
for features, label in training:
  X_test.append(features)
  y_test.append(label)
X_test = np.array(X_test).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X_test = X_test.astype('float32')
X_test /= 255
X_test = np.array(X_test)
y_test = np.array(y_test)

path_test = "E:/project_final/mixed/split_final_const/val/"
training = []
createTrainingData()
X_val =[]
y_val =[]
for features, label in training:
  X_val.append(features)
  y_val.append(label)
X_val = np.array(X_val).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X_val = X_val.astype('float32')
X_val /= 255
X_val = np.array(X_val)
y_val = np.array(y_val)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, IMG_CHANNELS)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation=None)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 128)       3584
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 128)      0
#  )
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 64)                4718656
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4,724,353
# Trainable params: 4,724,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
#tf.keras.utils.plot_model(
#    model,
#    to_file="model.png",
#    show_shapes=True,
#    show_dtype=False,
#    show_layer_names=False,
#    rankdir="TB",
#    expand_nested=False,
#    dpi=96,
#)

# %%
model.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 434/434 [==============================] - 105s 88ms/step - loss: 69.6474 - root_mean_squared_error: 8.3455 - val_loss: 36.7559 - val_root_mean_squared_error: 6.0627
# Epoch 2/50
# 434/434 [==============================] - 37s 85ms/step - loss: 41.2467 - root_mean_squared_error: 6.4224 - val_loss: 41.0861 - val_root_mean_squared_error: 6.4098
# Epoch 3/50
# 434/434 [==============================] - 37s 86ms/step - loss: 35.6421 - root_mean_squared_error: 5.9701 - val_loss: 34.0461 - val_root_mean_squared_error: 5.8349
# Epoch 4/50
# 434/434 [==============================] - 37s 86ms/step - loss: 36.8702 - root_mean_squared_error: 6.0721 - val_loss: 54.0285 - val_root_mean_squared_error: 7.3504
# Epoch 5/50
# 434/434 [==============================] - 37s 86ms/step - loss: 34.6271 - root_mean_squared_error: 5.8845 - val_loss: 33.0482 - val_root_mean_squared_error: 5.7488
# Epoch 6/50
# 434/434 [==============================] - 38s 87ms/step - loss: 32.4557 - root_mean_squared_error: 5.6970 - val_loss: 26.2051 - val_root_mean_squared_error: 5.1191
# Epoch 7/50
# 434/434 [==============================] - 38s 87ms/step - loss: 30.4604 - root_mean_squared_error: 5.5191 - val_loss: 59.7455 - val_root_mean_squared_error: 7.7295
# Epoch 8/50
# 434/434 [==============================] - 38s 87ms/step - loss: 30.8107 - root_mean_squared_error: 5.5507 - val_loss: 61.6703 - val_root_mean_squared_error: 7.8530
# Epoch 9/50
# 434/434 [==============================] - 38s 87ms/step - loss: 28.9127 - root_mean_squared_error: 5.3771 - val_loss: 31.0686 - val_root_mean_squared_error: 5.5739
# Epoch 10/50
# 434/434 [==============================] - 38s 87ms/step - loss: 31.7213 - root_mean_squared_error: 5.6322 - val_loss: 22.7865 - val_root_mean_squared_error: 4.7735
# Epoch 11/50
# 434/434 [==============================] - 38s 87ms/step - loss: 26.7343 - root_mean_squared_error: 5.1705 - val_loss: 39.9587 - val_root_mean_squared_error: 6.3213
# Epoch 12/50
# 434/434 [==============================] - 37s 86ms/step - loss: 29.6870 - root_mean_squared_error: 5.4486 - val_loss: 37.0831 - val_root_mean_squared_error: 6.0896
# Epoch 13/50
# 434/434 [==============================] - 37s 86ms/step - loss: 29.0243 - root_mean_squared_error: 5.3874 - val_loss: 23.4529 - val_root_mean_squared_error: 4.8428
# Epoch 14/50
# 434/434 [==============================] - 38s 87ms/step - loss: 25.9728 - root_mean_squared_error: 5.0964 - val_loss: 42.6119 - val_root_mean_squared_error: 6.5278
# Epoch 15/50
# 434/434 [==============================] - 38s 87ms/step - loss: 24.5468 - root_mean_squared_error: 4.9545 - val_loss: 34.6953 - val_root_mean_squared_error: 5.8903
# Epoch 16/50
# 434/434 [==============================] - 38s 88ms/step - loss: 24.1836 - root_mean_squared_error: 4.9177 - val_loss: 18.8048 - val_root_mean_squared_error: 4.3365
# Epoch 17/50
# 434/434 [==============================] - 38s 88ms/step - loss: 19.8256 - root_mean_squared_error: 4.4526 - val_loss: 25.3647 - val_root_mean_squared_error: 5.0363
# Epoch 18/50
# 434/434 [==============================] - 38s 88ms/step - loss: 17.6408 - root_mean_squared_error: 4.2001 - val_loss: 15.7933 - val_root_mean_squared_error: 3.9741
# Epoch 19/50
# 434/434 [==============================] - 38s 88ms/step - loss: 19.0922 - root_mean_squared_error: 4.3695 - val_loss: 13.2868 - val_root_mean_squared_error: 3.6451
# Epoch 20/50
# 434/434 [==============================] - 38s 87ms/step - loss: 17.6125 - root_mean_squared_error: 4.1967 - val_loss: 18.1518 - val_root_mean_squared_error: 4.2605
# Epoch 21/50
# 434/434 [==============================] - 38s 87ms/step - loss: 16.6856 - root_mean_squared_error: 4.0848 - val_loss: 12.9287 - val_root_mean_squared_error: 3.5956
# Epoch 22/50
# 434/434 [==============================] - 38s 87ms/step - loss: 12.7788 - root_mean_squared_error: 3.5747 - val_loss: 9.4354 - val_root_mean_squared_error: 3.0717
# Epoch 23/50
# 434/434 [==============================] - 38s 87ms/step - loss: 16.0986 - root_mean_squared_error: 4.0123 - val_loss: 7.2765 - val_root_mean_squared_error: 2.6975
# Epoch 24/50
# 434/434 [==============================] - 37s 86ms/step - loss: 11.0292 - root_mean_squared_error: 3.3210 - val_loss: 6.5414 - val_root_mean_squared_error: 2.5576
# Epoch 25/50
# 434/434 [==============================] - 38s 87ms/step - loss: 13.5980 - root_mean_squared_error: 3.6875 - val_loss: 12.4833 - val_root_mean_squared_error: 3.5332
# Epoch 26/50
# 434/434 [==============================] - 38s 87ms/step - loss: 11.5207 - root_mean_squared_error: 3.3942 - val_loss: 16.1935 - val_root_mean_squared_error: 4.0241
# Epoch 27/50
# 434/434 [==============================] - 38s 87ms/step - loss: 11.1829 - root_mean_squared_error: 3.3441 - val_loss: 5.5401 - val_root_mean_squared_error: 2.3537
# Epoch 28/50
# 434/434 [==============================] - 38s 87ms/step - loss: 9.0857 - root_mean_squared_error: 3.0142 - val_loss: 14.7346 - val_root_mean_squared_error: 3.8386
# Epoch 29/50
# 434/434 [==============================] - 38s 87ms/step - loss: 9.4187 - root_mean_squared_error: 3.0690 - val_loss: 9.7613 - val_root_mean_squared_error: 3.1243
# Epoch 30/50
# 434/434 [==============================] - 38s 87ms/step - loss: 10.7013 - root_mean_squared_error: 3.2713 - val_loss: 12.3026 - val_root_mean_squared_error: 3.5075
# Epoch 31/50
# 434/434 [==============================] - 38s 87ms/step - loss: 10.3226 - root_mean_squared_error: 3.2129 - val_loss: 5.8202 - val_root_mean_squared_error: 2.4125
# Epoch 32/50
# 434/434 [==============================] - 38s 87ms/step - loss: 9.4112 - root_mean_squared_error: 3.0678 - val_loss: 5.1255 - val_root_mean_squared_error: 2.2640
# Epoch 33/50
# 434/434 [==============================] - 38s 87ms/step - loss: 8.7364 - root_mean_squared_error: 2.9557 - val_loss: 12.2334 - val_root_mean_squared_error: 3.4976
# Epoch 34/50
# 434/434 [==============================] - 38s 87ms/step - loss: 8.6285 - root_mean_squared_error: 2.9374 - val_loss: 5.2747 - val_root_mean_squared_error: 2.2967
# Epoch 35/50
# 434/434 [==============================] - 38s 87ms/step - loss: 10.0590 - root_mean_squared_error: 3.1716 - val_loss: 5.7070 - val_root_mean_squared_error: 2.3889
# Epoch 36/50
# 434/434 [==============================] - 38s 87ms/step - loss: 8.8696 - root_mean_squared_error: 2.9782 - val_loss: 21.3663 - val_root_mean_squared_error: 4.6224
# Epoch 37/50
# 434/434 [==============================] - 38s 86ms/step - loss: 11.6013 - root_mean_squared_error: 3.4061 - val_loss: 4.7390 - val_root_mean_squared_error: 2.1769
# Epoch 38/50
# 434/434 [==============================] - 38s 87ms/step - loss: 6.3174 - root_mean_squared_error: 2.5134 - val_loss: 6.2585 - val_root_mean_squared_error: 2.5017
# Epoch 39/50
# 434/434 [==============================] - 38s 87ms/step - loss: 8.9675 - root_mean_squared_error: 2.9946 - val_loss: 4.5628 - val_root_mean_squared_error: 2.1361
# Epoch 40/50
# 434/434 [==============================] - 38s 87ms/step - loss: 7.2491 - root_mean_squared_error: 2.6924 - val_loss: 6.6541 - val_root_mean_squared_error: 2.5796
# Epoch 41/50
# 434/434 [==============================] - 38s 87ms/step - loss: 6.0934 - root_mean_squared_error: 2.4685 - val_loss: 4.6725 - val_root_mean_squared_error: 2.1616
# Epoch 42/50
# 434/434 [==============================] - 38s 87ms/step - loss: 10.4422 - root_mean_squared_error: 3.2314 - val_loss: 20.1540 - val_root_mean_squared_error: 4.4893
# Epoch 43/50
# 434/434 [==============================] - 38s 87ms/step - loss: 8.4835 - root_mean_squared_error: 2.9126 - val_loss: 16.5663 - val_root_mean_squared_error: 4.0702
# Epoch 44/50
# 434/434 [==============================] - 38s 87ms/step - loss: 7.4835 - root_mean_squared_error: 2.7356 - val_loss: 3.7984 - val_root_mean_squared_error: 1.9489
# Epoch 45/50
# 434/434 [==============================] - 38s 87ms/step - loss: 10.4605 - root_mean_squared_error: 3.2343 - val_loss: 7.5226 - val_root_mean_squared_error: 2.7427
# Epoch 46/50
# 434/434 [==============================] - 38s 87ms/step - loss: 7.6103 - root_mean_squared_error: 2.7587 - val_loss: 6.7347 - val_root_mean_squared_error: 2.5951
# Epoch 47/50
# 434/434 [==============================] - 38s 87ms/step - loss: 9.5696 - root_mean_squared_error: 3.0935 - val_loss: 3.7501 - val_root_mean_squared_error: 1.9365
# Epoch 48/50
# 434/434 [==============================] - 38s 87ms/step - loss: 5.8520 - root_mean_squared_error: 2.4191 - val_loss: 10.6695 - val_root_mean_squared_error: 3.2664
# Epoch 49/50
# 434/434 [==============================] - 38s 87ms/step - loss: 7.0635 - root_mean_squared_error: 2.6577 - val_loss: 7.0431 - val_root_mean_squared_error: 2.6539
# Epoch 50/50
# 434/434 [==============================] - 38s 87ms/step - loss: 6.5232 - root_mean_squared_error: 2.5540 - val_loss: 5.8652 - val_root_mean_squared_error: 2.4218

# %%
training_plot(['loss', 'root_mean_squared_error'], history)

# %%
prediction = model.predict(X_test)

#create basic scatterplot
plt.plot(y_test, prediction, '.')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(y_test, prediction, 1)

#add linear regression line to scatterplot 
plt.plot(y_test, m*y_test+b)
plt.grid()
plt.xlabel('original [μg/ml]') 
plt.ylabel('predicted [μg/ml]') 

# model evaluation 
mse=mean_squared_error(y_test,prediction) 
rmse = np.sqrt(mean_squared_error(y_test,prediction)) 
r2 = r2_score(y_test,prediction) 

# printing values 
print('Slope:' , m) 
print('Intercept:', b) 
print('MSE:', mse) 
print('Root mean squared error: ', rmse) 
print('R2 score: ', r2)
# Out:
# 93/93 [==============================] - 3s 29ms/step
# Slope: [1.01120245]
# Intercept: [0.02032855]
# MSE: 7.9583669355575095
# Root mean squared error:  2.821057768915325
# R2 score:  0.9896778264103196

# %%
prediction_g=prediction.reshape(-1, 330)
mean_pred=[]
std_pred=[]
for i in range(9):
    mean_pred.append(np.mean(prediction_g[i]))
    std_pred.append(np.std(prediction_g[i]))

plt.errorbar(CAT, mean_pred, std_pred, linestyle='None', marker='.')
plt.plot(CAT, m*CAT+b)
plt.grid()
plt.xlabel('original [μg/ml]') 
plt.ylabel('predicted [μg/ml]') 

plt.show()
